# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 907us/sample - loss: 240.6329 - y1_output_loss: 113.1484 - y2_output_loss: 125.8155 - y1_output_root_mean_squared_error: 10.6702 - y2_output_root_mean_squared_error: 11.2597 - val_loss: 64.2499 - val_y1_output_loss: 22.1096 - val_y2_output_loss: 43.3267 - val_y1_output_root_mean_squared_error: 4.6784 - val_y2_output_root_mean_squared_error: 6.5087
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 28.1117 - y1_output_loss: 11.5284 - y2_output_loss: 16.4203 - y1_output_root_mean_squared_error: 3.4065 - y2_output_root_mean_squared_error: 4.0630 - val_loss: 43.0500 - val_y1_output_loss: 15.8134 - val_y2_output_loss: 26.1066 - val_y1_output_root_mean_squared_error: 4.0278 - val_y2_output_root_mean_squared_error: 5.1795
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.8182 - y1_output_loss: 9.5698 - y2_output_loss: 13.1846 - y1_output_root_mean_squared_error: 3.0903 - y2_output_root_mean_squared_error: 3.6426 - val_loss: 26.8134 - val_y1_output_loss: 11.5216 - val_y2_output_loss: 14.7594 - val_y1_output_root_mean_squared_error: 3.4199 - val_y2_output_root_mean_squared_error: 3.8882
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.3326 - y1_output_loss: 8.9926 - y2_output_loss: 13.3229 - y1_output_root_mean_squared_error: 2.9988 - y2_output_root_mean_squared_error: 3.6524 - val_loss: 49.3165 - val_y1_output_loss: 16.1415 - val_y2_output_loss: 32.1762 - val_y1_output_root_mean_squared_error: 4.0610 - val_y2_output_root_mean_squared_error: 5.7293
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 23.4581 - y1_output_loss: 9.2679 - y2_output_loss: 14.0808 - y1_output_root_mean_squared_error: 3.0429 - y2_output_root_mean_squared_error: 3.7681 - val_loss: 23.1879 - val_y1_output_loss: 9.8818 - val_y2_output_loss: 13.2549 - val_y1_output_root_mean_squared_error: 3.1261 - val_y2_output_root_mean_squared_error: 3.6627
# Epoch 6/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.0744 - y1_output_loss: 8.3077 - y2_output_loss: 11.7052 - y1_output_root_mean_squared_error: 2.8865 - y2_output_root_mean_squared_error: 3.4267 - val_loss: 23.5527 - val_y1_output_loss: 10.3251 - val_y2_output_loss: 13.2466 - val_y1_output_root_mean_squared_error: 3.2209 - val_y2_output_root_mean_squared_error: 3.6302
# Epoch 7/500
# 614/614 [==============================] - 0s 132us/sample - loss: 22.1921 - y1_output_loss: 8.4142 - y2_output_loss: 13.6969 - y1_output_root_mean_squared_error: 2.8967 - y2_output_root_mean_squared_error: 3.7150 - val_loss: 32.4219 - val_y1_output_loss: 11.0487 - val_y2_output_loss: 20.8845 - val_y1_output_root_mean_squared_error: 3.3394 - val_y2_output_root_mean_squared_error: 4.6120
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.8084 - y1_output_loss: 8.2207 - y2_output_loss: 11.5503 - y1_output_root_mean_squared_error: 2.8718 - y2_output_root_mean_squared_error: 3.4002 - val_loss: 27.3946 - val_y1_output_loss: 10.2480 - val_y2_output_loss: 17.2568 - val_y1_output_root_mean_squared_error: 3.1692 - val_y2_output_root_mean_squared_error: 4.1655
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.2712 - y1_output_loss: 7.9152 - y2_output_loss: 12.3020 - y1_output_root_mean_squared_error: 2.8214 - y2_output_root_mean_squared_error: 3.5087 - val_loss: 27.4366 - val_y1_output_loss: 9.9814 - val_y2_output_loss: 18.8139 - val_y1_output_root_mean_squared_error: 3.0717 - val_y2_output_root_mean_squared_error: 4.2428
# Epoch 10/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.0652 - y1_output_loss: 8.1833 - y2_output_loss: 12.7019 - y1_output_root_mean_squared_error: 2.8731 - y2_output_root_mean_squared_error: 3.5792 - val_loss: 22.2582 - val_y1_output_loss: 8.9546 - val_y2_output_loss: 13.6976 - val_y1_output_root_mean_squared_error: 2.9456 - val_y2_output_root_mean_squared_error: 3.6853
# Epoch 11/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.2267 - y1_output_loss: 7.8422 - y2_output_loss: 12.3691 - y1_output_root_mean_squared_error: 2.7971 - y2_output_root_mean_squared_error: 3.5218 - val_loss: 27.1968 - val_y1_output_loss: 9.9185 - val_y2_output_loss: 18.1032 - val_y1_output_root_mean_squared_error: 3.1098 - val_y2_output_root_mean_squared_error: 4.1864
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.8838 - y1_output_loss: 7.3267 - y2_output_loss: 11.5205 - y1_output_root_mean_squared_error: 2.6969 - y2_output_root_mean_squared_error: 3.4074 - val_loss: 26.6952 - val_y1_output_loss: 11.3710 - val_y2_output_loss: 16.1052 - val_y1_output_root_mean_squared_error: 3.3205 - val_y2_output_root_mean_squared_error: 3.9585
# Epoch 13/500
# 614/614 [==============================] - 0s 141us/sample - loss: 18.8747 - y1_output_loss: 7.4984 - y2_output_loss: 11.3155 - y1_output_root_mean_squared_error: 2.7468 - y2_output_root_mean_squared_error: 3.3660 - val_loss: 22.7133 - val_y1_output_loss: 8.5335 - val_y2_output_loss: 15.2489 - val_y1_output_root_mean_squared_error: 2.8552 - val_y2_output_root_mean_squared_error: 3.8159
# Epoch 14/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.6784 - y1_output_loss: 7.1041 - y2_output_loss: 10.5598 - y1_output_root_mean_squared_error: 2.6742 - y2_output_root_mean_squared_error: 3.2446 - val_loss: 33.7236 - val_y1_output_loss: 9.8696 - val_y2_output_loss: 26.1559 - val_y1_output_root_mean_squared_error: 3.0291 - val_y2_output_root_mean_squared_error: 4.9546
# Epoch 15/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.1666 - y1_output_loss: 7.0143 - y2_output_loss: 10.1598 - y1_output_root_mean_squared_error: 2.6387 - y2_output_root_mean_squared_error: 3.1943 - val_loss: 20.1673 - val_y1_output_loss: 8.3231 - val_y2_output_loss: 11.9804 - val_y1_output_root_mean_squared_error: 2.8652 - val_y2_output_root_mean_squared_error: 3.4581
# Epoch 16/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.6163 - y1_output_loss: 6.7366 - y2_output_loss: 10.7401 - y1_output_root_mean_squared_error: 2.6040 - y2_output_root_mean_squared_error: 3.2918 - val_loss: 17.8823 - val_y1_output_loss: 7.2917 - val_y2_output_loss: 10.6868 - val_y1_output_root_mean_squared_error: 2.6845 - val_y2_output_root_mean_squared_error: 3.2674
# Epoch 17/500
# 614/614 [==============================] - 0s 131us/sample - loss: 15.1080 - y1_output_loss: 6.0605 - y2_output_loss: 9.0767 - y1_output_root_mean_squared_error: 2.4708 - y2_output_root_mean_squared_error: 3.0005 - val_loss: 22.8599 - val_y1_output_loss: 8.4173 - val_y2_output_loss: 14.2468 - val_y1_output_root_mean_squared_error: 2.8982 - val_y2_output_root_mean_squared_error: 3.8027
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.4853 - y1_output_loss: 6.2787 - y2_output_loss: 10.4478 - y1_output_root_mean_squared_error: 2.4806 - y2_output_root_mean_squared_error: 3.2144 - val_loss: 63.4966 - val_y1_output_loss: 19.4769 - val_y2_output_loss: 43.5153 - val_y1_output_root_mean_squared_error: 4.4237 - val_y2_output_root_mean_squared_error: 6.6278
# Epoch 19/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.9679 - y1_output_loss: 6.1041 - y2_output_loss: 9.8276 - y1_output_root_mean_squared_error: 2.4727 - y2_output_root_mean_squared_error: 3.1390 - val_loss: 22.2215 - val_y1_output_loss: 8.0982 - val_y2_output_loss: 13.8189 - val_y1_output_root_mean_squared_error: 2.8517 - val_y2_output_root_mean_squared_error: 3.7536
# Epoch 20/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.0219 - y1_output_loss: 5.9148 - y2_output_loss: 10.0127 - y1_output_root_mean_squared_error: 2.4363 - y2_output_root_mean_squared_error: 3.1759 - val_loss: 15.4126 - val_y1_output_loss: 6.2599 - val_y2_output_loss: 9.5312 - val_y1_output_root_mean_squared_error: 2.4705 - val_y2_output_root_mean_squared_error: 3.0511
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.1234 - y1_output_loss: 5.3945 - y2_output_loss: 7.6696 - y1_output_root_mean_squared_error: 2.3308 - y2_output_root_mean_squared_error: 2.7732 - val_loss: 19.1929 - val_y1_output_loss: 6.2915 - val_y2_output_loss: 12.8639 - val_y1_output_root_mean_squared_error: 2.4837 - val_y2_output_root_mean_squared_error: 3.6089
# Epoch 22/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.3054 - y1_output_loss: 4.9283 - y2_output_loss: 7.3329 - y1_output_root_mean_squared_error: 2.2297 - y2_output_root_mean_squared_error: 2.7081 - val_loss: 15.8582 - val_y1_output_loss: 5.9618 - val_y2_output_loss: 10.9166 - val_y1_output_root_mean_squared_error: 2.3629 - val_y2_output_root_mean_squared_error: 3.2055
# Epoch 23/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.5590 - y1_output_loss: 5.4218 - y2_output_loss: 9.4552 - y1_output_root_mean_squared_error: 2.3194 - y2_output_root_mean_squared_error: 3.0297 - val_loss: 36.9539 - val_y1_output_loss: 10.7701 - val_y2_output_loss: 28.6060 - val_y1_output_root_mean_squared_error: 3.1704 - val_y2_output_root_mean_squared_error: 5.1867
# Epoch 24/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.9518 - y1_output_loss: 5.0135 - y2_output_loss: 6.9292 - y1_output_root_mean_squared_error: 2.2377 - y2_output_root_mean_squared_error: 2.6352 - val_loss: 27.7280 - val_y1_output_loss: 6.9749 - val_y2_output_loss: 20.3314 - val_y1_output_root_mean_squared_error: 2.6398 - val_y2_output_root_mean_squared_error: 4.5563
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.0541 - y1_output_loss: 4.7260 - y2_output_loss: 7.3094 - y1_output_root_mean_squared_error: 2.1678 - y2_output_root_mean_squared_error: 2.7120 - val_loss: 24.0039 - val_y1_output_loss: 7.2866 - val_y2_output_loss: 16.4464 - val_y1_output_root_mean_squared_error: 2.6932 - val_y2_output_root_mean_squared_error: 4.0927
# Epoch 26/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.9329 - y1_output_loss: 4.6680 - y2_output_loss: 8.2211 - y1_output_root_mean_squared_error: 2.1693 - y2_output_root_mean_squared_error: 2.8683 - val_loss: 29.2067 - val_y1_output_loss: 7.9341 - val_y2_output_loss: 23.1441 - val_y1_output_root_mean_squared_error: 2.7251 - val_y2_output_root_mean_squared_error: 4.6669
# Epoch 27/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.5782 - y1_output_loss: 4.2199 - y2_output_loss: 6.3465 - y1_output_root_mean_squared_error: 2.0632 - y2_output_root_mean_squared_error: 2.5143 - val_loss: 13.5513 - val_y1_output_loss: 5.0504 - val_y2_output_loss: 9.1576 - val_y1_output_root_mean_squared_error: 2.2008 - val_y2_output_root_mean_squared_error: 2.9509
# Epoch 28/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.4169 - y1_output_loss: 4.3973 - y2_output_loss: 7.2176 - y1_output_root_mean_squared_error: 2.0936 - y2_output_root_mean_squared_error: 2.6521 - val_loss: 39.9855 - val_y1_output_loss: 11.9304 - val_y2_output_loss: 28.5362 - val_y1_output_root_mean_squared_error: 3.4417 - val_y2_output_root_mean_squared_error: 5.3047
# Epoch 29/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.7099 - y1_output_loss: 4.6398 - y2_output_loss: 7.9688 - y1_output_root_mean_squared_error: 2.1623 - y2_output_root_mean_squared_error: 2.8345 - val_loss: 14.7720 - val_y1_output_loss: 5.7562 - val_y2_output_loss: 9.3303 - val_y1_output_root_mean_squared_error: 2.3480 - val_y2_output_root_mean_squared_error: 3.0429
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.6057 - y1_output_loss: 4.0448 - y2_output_loss: 6.6698 - y1_output_root_mean_squared_error: 1.9937 - y2_output_root_mean_squared_error: 2.5750 - val_loss: 17.0069 - val_y1_output_loss: 6.1118 - val_y2_output_loss: 10.6821 - val_y1_output_root_mean_squared_error: 2.4750 - val_y2_output_root_mean_squared_error: 3.2986
# Epoch 31/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.9422 - y1_output_loss: 3.6143 - y2_output_loss: 6.2390 - y1_output_root_mean_squared_error: 1.9091 - y2_output_root_mean_squared_error: 2.5095 - val_loss: 13.6267 - val_y1_output_loss: 5.2736 - val_y2_output_loss: 9.2978 - val_y1_output_root_mean_squared_error: 2.2074 - val_y2_output_root_mean_squared_error: 2.9587
# Epoch 32/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.8731 - y1_output_loss: 3.5828 - y2_output_loss: 6.3433 - y1_output_root_mean_squared_error: 1.8970 - y2_output_root_mean_squared_error: 2.5049 - val_loss: 36.9469 - val_y1_output_loss: 7.9913 - val_y2_output_loss: 30.8663 - val_y1_output_root_mean_squared_error: 2.7436 - val_y2_output_root_mean_squared_error: 5.4240
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.7446 - y1_output_loss: 3.6015 - y2_output_loss: 7.1604 - y1_output_root_mean_squared_error: 1.9034 - y2_output_root_mean_squared_error: 2.6686 - val_loss: 11.5973 - val_y1_output_loss: 4.4785 - val_y2_output_loss: 7.7793 - val_y1_output_root_mean_squared_error: 2.0430 - val_y2_output_root_mean_squared_error: 2.7246
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.0393 - y1_output_loss: 3.3716 - y2_output_loss: 6.6571 - y1_output_root_mean_squared_error: 1.8386 - y2_output_root_mean_squared_error: 2.5805 - val_loss: 11.3372 - val_y1_output_loss: 3.4931 - val_y2_output_loss: 7.9387 - val_y1_output_root_mean_squared_error: 1.8191 - val_y2_output_root_mean_squared_error: 2.8334
# Epoch 35/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.0609 - y1_output_loss: 3.2404 - y2_output_loss: 6.7439 - y1_output_root_mean_squared_error: 1.8055 - y2_output_root_mean_squared_error: 2.6079 - val_loss: 9.8580 - val_y1_output_loss: 3.6783 - val_y2_output_loss: 6.6823 - val_y1_output_root_mean_squared_error: 1.8455 - val_y2_output_root_mean_squared_error: 2.5401
# Epoch 36/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.6514 - y1_output_loss: 2.8770 - y2_output_loss: 5.7268 - y1_output_root_mean_squared_error: 1.7040 - y2_output_root_mean_squared_error: 2.3974 - val_loss: 11.0633 - val_y1_output_loss: 3.7394 - val_y2_output_loss: 7.5523 - val_y1_output_root_mean_squared_error: 1.8859 - val_y2_output_root_mean_squared_error: 2.7399
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.7707 - y1_output_loss: 2.7649 - y2_output_loss: 5.1065 - y1_output_root_mean_squared_error: 1.6621 - y2_output_root_mean_squared_error: 2.2378 - val_loss: 21.7371 - val_y1_output_loss: 4.4434 - val_y2_output_loss: 18.3214 - val_y1_output_root_mean_squared_error: 2.0568 - val_y2_output_root_mean_squared_error: 4.1841
# Epoch 38/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.0536 - y1_output_loss: 2.6904 - y2_output_loss: 5.3025 - y1_output_root_mean_squared_error: 1.6451 - y2_output_root_mean_squared_error: 2.3124 - val_loss: 11.6185 - val_y1_output_loss: 3.9926 - val_y2_output_loss: 8.1541 - val_y1_output_root_mean_squared_error: 1.9480 - val_y2_output_root_mean_squared_error: 2.7971
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.0396 - y1_output_loss: 2.6253 - y2_output_loss: 5.3423 - y1_output_root_mean_squared_error: 1.6274 - y2_output_root_mean_squared_error: 2.3219 - val_loss: 8.9517 - val_y1_output_loss: 2.9968 - val_y2_output_loss: 5.9340 - val_y1_output_root_mean_squared_error: 1.7177 - val_y2_output_root_mean_squared_error: 2.4497
# Epoch 40/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.0857 - y1_output_loss: 3.4596 - y2_output_loss: 6.7640 - y1_output_root_mean_squared_error: 1.8532 - y2_output_root_mean_squared_error: 2.5790 - val_loss: 37.8648 - val_y1_output_loss: 9.6959 - val_y2_output_loss: 27.9816 - val_y1_output_root_mean_squared_error: 3.0949 - val_y2_output_root_mean_squared_error: 5.3185
# Epoch 41/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.8601 - y1_output_loss: 2.3925 - y2_output_loss: 4.4233 - y1_output_root_mean_squared_error: 1.5509 - y2_output_root_mean_squared_error: 2.1107 - val_loss: 8.3029 - val_y1_output_loss: 2.6902 - val_y2_output_loss: 5.6817 - val_y1_output_root_mean_squared_error: 1.6201 - val_y2_output_root_mean_squared_error: 2.3829
# Epoch 42/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.5832 - y1_output_loss: 2.8738 - y2_output_loss: 6.6738 - y1_output_root_mean_squared_error: 1.6927 - y2_output_root_mean_squared_error: 2.5919 - val_loss: 11.0702 - val_y1_output_loss: 3.9792 - val_y2_output_loss: 7.0728 - val_y1_output_root_mean_squared_error: 1.9714 - val_y2_output_root_mean_squared_error: 2.6803
# Epoch 43/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9422 - y1_output_loss: 2.3295 - y2_output_loss: 4.8577 - y1_output_root_mean_squared_error: 1.5023 - y2_output_root_mean_squared_error: 2.1646 - val_loss: 95.8580 - val_y1_output_loss: 32.2480 - val_y2_output_loss: 62.1042 - val_y1_output_root_mean_squared_error: 5.7246 - val_y2_output_root_mean_squared_error: 7.9427
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.0391 - y1_output_loss: 2.8245 - y2_output_loss: 6.1315 - y1_output_root_mean_squared_error: 1.6880 - y2_output_root_mean_squared_error: 2.4879 - val_loss: 9.6699 - val_y1_output_loss: 2.7471 - val_y2_output_loss: 7.0419 - val_y1_output_root_mean_squared_error: 1.6015 - val_y2_output_root_mean_squared_error: 2.6656
# Epoch 45/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.6496 - y1_output_loss: 2.8389 - y2_output_loss: 5.7683 - y1_output_root_mean_squared_error: 1.6881 - y2_output_root_mean_squared_error: 2.4083 - val_loss: 12.3882 - val_y1_output_loss: 3.7489 - val_y2_output_loss: 9.2748 - val_y1_output_root_mean_squared_error: 1.8700 - val_y2_output_root_mean_squared_error: 2.9818
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.2906 - y1_output_loss: 3.8148 - y2_output_loss: 8.3753 - y1_output_root_mean_squared_error: 1.9595 - y2_output_root_mean_squared_error: 2.9070 - val_loss: 17.0476 - val_y1_output_loss: 4.2914 - val_y2_output_loss: 12.5492 - val_y1_output_root_mean_squared_error: 2.0614 - val_y2_output_root_mean_squared_error: 3.5774
# Epoch 47/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.1604 - y1_output_loss: 2.2203 - y2_output_loss: 4.9386 - y1_output_root_mean_squared_error: 1.4884 - y2_output_root_mean_squared_error: 2.2237 - val_loss: 14.5629 - val_y1_output_loss: 4.5761 - val_y2_output_loss: 9.8561 - val_y1_output_root_mean_squared_error: 2.1246 - val_y2_output_root_mean_squared_error: 3.1700
# Epoch 48/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.6005 - y1_output_loss: 1.8451 - y2_output_loss: 3.7112 - y1_output_root_mean_squared_error: 1.3626 - y2_output_root_mean_squared_error: 1.9349 - val_loss: 9.1241 - val_y1_output_loss: 2.5428 - val_y2_output_loss: 6.6092 - val_y1_output_root_mean_squared_error: 1.5562 - val_y2_output_root_mean_squared_error: 2.5889
# Epoch 49/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6196 - y1_output_loss: 2.0771 - y2_output_loss: 4.5051 - y1_output_root_mean_squared_error: 1.4444 - y2_output_root_mean_squared_error: 2.1292 - val_loss: 11.0987 - val_y1_output_loss: 2.5213 - val_y2_output_loss: 8.9239 - val_y1_output_root_mean_squared_error: 1.5477 - val_y2_output_root_mean_squared_error: 2.9501
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.9193 - y1_output_loss: 2.0710 - y2_output_loss: 4.7883 - y1_output_root_mean_squared_error: 1.4454 - y2_output_root_mean_squared_error: 2.1978 - val_loss: 9.1281 - val_y1_output_loss: 2.6578 - val_y2_output_loss: 6.3792 - val_y1_output_root_mean_squared_error: 1.6132 - val_y2_output_root_mean_squared_error: 2.5546
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6932 - y1_output_loss: 2.0995 - y2_output_loss: 4.5735 - y1_output_root_mean_squared_error: 1.4421 - y2_output_root_mean_squared_error: 2.1479 - val_loss: 7.7018 - val_y1_output_loss: 2.5038 - val_y2_output_loss: 5.3995 - val_y1_output_root_mean_squared_error: 1.5274 - val_y2_output_root_mean_squared_error: 2.3171
# Epoch 52/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.5308 - y1_output_loss: 1.9322 - y2_output_loss: 4.6273 - y1_output_root_mean_squared_error: 1.3956 - y2_output_root_mean_squared_error: 2.1408 - val_loss: 27.3023 - val_y1_output_loss: 5.7380 - val_y2_output_loss: 22.4826 - val_y1_output_root_mean_squared_error: 2.3439 - val_y2_output_root_mean_squared_error: 4.6700
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5042 - y1_output_loss: 1.9138 - y2_output_loss: 4.5320 - y1_output_root_mean_squared_error: 1.3899 - y2_output_root_mean_squared_error: 2.1383 - val_loss: 9.3477 - val_y1_output_loss: 2.7972 - val_y2_output_loss: 6.5862 - val_y1_output_root_mean_squared_error: 1.6343 - val_y2_output_root_mean_squared_error: 2.5839
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9682 - y1_output_loss: 2.0212 - y2_output_loss: 4.9145 - y1_output_root_mean_squared_error: 1.4209 - y2_output_root_mean_squared_error: 2.2247 - val_loss: 13.5977 - val_y1_output_loss: 4.9221 - val_y2_output_loss: 8.5365 - val_y1_output_root_mean_squared_error: 2.2113 - val_y2_output_root_mean_squared_error: 2.9509
# Epoch 55/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.3498 - y1_output_loss: 1.7180 - y2_output_loss: 3.6104 - y1_output_root_mean_squared_error: 1.3137 - y2_output_root_mean_squared_error: 1.9037 - val_loss: 7.8239 - val_y1_output_loss: 2.3037 - val_y2_output_loss: 5.5005 - val_y1_output_root_mean_squared_error: 1.5074 - val_y2_output_root_mean_squared_error: 2.3562
# Epoch 56/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.9013 - y1_output_loss: 2.4930 - y2_output_loss: 5.3587 - y1_output_root_mean_squared_error: 1.5821 - y2_output_root_mean_squared_error: 2.3234 - val_loss: 10.0764 - val_y1_output_loss: 3.0475 - val_y2_output_loss: 6.9805 - val_y1_output_root_mean_squared_error: 1.7205 - val_y2_output_root_mean_squared_error: 2.6676
# Epoch 57/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.5735 - y1_output_loss: 1.6339 - y2_output_loss: 3.9125 - y1_output_root_mean_squared_error: 1.2740 - y2_output_root_mean_squared_error: 1.9876 - val_loss: 7.3252 - val_y1_output_loss: 2.2096 - val_y2_output_loss: 5.1953 - val_y1_output_root_mean_squared_error: 1.4580 - val_y2_output_root_mean_squared_error: 2.2802
# Epoch 58/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.4780 - y1_output_loss: 1.6270 - y2_output_loss: 3.8015 - y1_output_root_mean_squared_error: 1.2817 - y2_output_root_mean_squared_error: 1.9584 - val_loss: 6.4003 - val_y1_output_loss: 1.5665 - val_y2_output_loss: 4.8247 - val_y1_output_root_mean_squared_error: 1.2333 - val_y2_output_root_mean_squared_error: 2.2089
# Epoch 59/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.9685 - y1_output_loss: 1.7295 - y2_output_loss: 4.2099 - y1_output_root_mean_squared_error: 1.3180 - y2_output_root_mean_squared_error: 2.0571 - val_loss: 8.5555 - val_y1_output_loss: 2.6075 - val_y2_output_loss: 5.9604 - val_y1_output_root_mean_squared_error: 1.5906 - val_y2_output_root_mean_squared_error: 2.4547
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6604 - y1_output_loss: 1.3992 - y2_output_loss: 3.2691 - y1_output_root_mean_squared_error: 1.1788 - y2_output_root_mean_squared_error: 1.8085 - val_loss: 9.1231 - val_y1_output_loss: 2.1920 - val_y2_output_loss: 7.1298 - val_y1_output_root_mean_squared_error: 1.4473 - val_y2_output_root_mean_squared_error: 2.6511
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2398 - y1_output_loss: 1.7179 - y2_output_loss: 4.5453 - y1_output_root_mean_squared_error: 1.3006 - y2_output_root_mean_squared_error: 2.1327 - val_loss: 6.3317 - val_y1_output_loss: 1.5546 - val_y2_output_loss: 4.8411 - val_y1_output_root_mean_squared_error: 1.2211 - val_y2_output_root_mean_squared_error: 2.2001
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.7720 - y1_output_loss: 1.3499 - y2_output_loss: 3.4606 - y1_output_root_mean_squared_error: 1.1626 - y2_output_root_mean_squared_error: 1.8494 - val_loss: 9.9307 - val_y1_output_loss: 3.6360 - val_y2_output_loss: 6.2780 - val_y1_output_root_mean_squared_error: 1.8925 - val_y2_output_root_mean_squared_error: 2.5198
# Epoch 63/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.1314 - y1_output_loss: 1.5188 - y2_output_loss: 3.6339 - y1_output_root_mean_squared_error: 1.2194 - y2_output_root_mean_squared_error: 1.9090 - val_loss: 7.3186 - val_y1_output_loss: 1.9152 - val_y2_output_loss: 5.4661 - val_y1_output_root_mean_squared_error: 1.3724 - val_y2_output_root_mean_squared_error: 2.3313
# Epoch 64/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2214 - y1_output_loss: 1.2488 - y2_output_loss: 2.9563 - y1_output_root_mean_squared_error: 1.1178 - y2_output_root_mean_squared_error: 1.7239 - val_loss: 6.5706 - val_y1_output_loss: 1.3069 - val_y2_output_loss: 5.3356 - val_y1_output_root_mean_squared_error: 1.1275 - val_y2_output_root_mean_squared_error: 2.3021
# Epoch 65/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.4992 - y1_output_loss: 1.2551 - y2_output_loss: 3.2512 - y1_output_root_mean_squared_error: 1.1210 - y2_output_root_mean_squared_error: 1.8007 - val_loss: 6.3429 - val_y1_output_loss: 1.4645 - val_y2_output_loss: 4.8890 - val_y1_output_root_mean_squared_error: 1.1836 - val_y2_output_root_mean_squared_error: 2.2231
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5672 - y1_output_loss: 1.3993 - y2_output_loss: 3.1433 - y1_output_root_mean_squared_error: 1.1819 - y2_output_root_mean_squared_error: 1.7805 - val_loss: 5.5569 - val_y1_output_loss: 1.3662 - val_y2_output_loss: 4.1732 - val_y1_output_root_mean_squared_error: 1.1512 - val_y2_output_root_mean_squared_error: 2.0571
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5713 - y1_output_loss: 1.2894 - y2_output_loss: 3.2589 - y1_output_root_mean_squared_error: 1.1340 - y2_output_root_mean_squared_error: 1.8126 - val_loss: 5.8531 - val_y1_output_loss: 1.4778 - val_y2_output_loss: 4.3426 - val_y1_output_root_mean_squared_error: 1.1966 - val_y2_output_root_mean_squared_error: 2.1027
# Epoch 68/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5372 - y1_output_loss: 1.1549 - y2_output_loss: 3.3480 - y1_output_root_mean_squared_error: 1.0767 - y2_output_root_mean_squared_error: 1.8379 - val_loss: 6.1158 - val_y1_output_loss: 1.3563 - val_y2_output_loss: 4.8131 - val_y1_output_root_mean_squared_error: 1.1222 - val_y2_output_root_mean_squared_error: 2.2037
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.2116 - y1_output_loss: 1.3731 - y2_output_loss: 3.8314 - y1_output_root_mean_squared_error: 1.1758 - y2_output_root_mean_squared_error: 1.9568 - val_loss: 7.2243 - val_y1_output_loss: 1.8417 - val_y2_output_loss: 5.5390 - val_y1_output_root_mean_squared_error: 1.3287 - val_y2_output_root_mean_squared_error: 2.3364
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.8785 - y1_output_loss: 1.5054 - y2_output_loss: 4.3176 - y1_output_root_mean_squared_error: 1.2326 - y2_output_root_mean_squared_error: 2.0879 - val_loss: 5.9302 - val_y1_output_loss: 1.3568 - val_y2_output_loss: 4.5261 - val_y1_output_root_mean_squared_error: 1.1416 - val_y2_output_root_mean_squared_error: 2.1510
# Epoch 71/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3892 - y1_output_loss: 1.1404 - y2_output_loss: 3.2749 - y1_output_root_mean_squared_error: 1.0558 - y2_output_root_mean_squared_error: 1.8096 - val_loss: 12.1035 - val_y1_output_loss: 4.0440 - val_y2_output_loss: 7.8341 - val_y1_output_root_mean_squared_error: 2.0246 - val_y2_output_root_mean_squared_error: 2.8292
# Epoch 72/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1670 - y1_output_loss: 1.0916 - y2_output_loss: 3.0606 - y1_output_root_mean_squared_error: 1.0495 - y2_output_root_mean_squared_error: 1.7508 - val_loss: 10.6447 - val_y1_output_loss: 2.3142 - val_y2_output_loss: 8.4551 - val_y1_output_root_mean_squared_error: 1.5096 - val_y2_output_root_mean_squared_error: 2.8924
# Epoch 73/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.3961 - y1_output_loss: 4.8069 - y2_output_loss: 10.4803 - y1_output_root_mean_squared_error: 2.2021 - y2_output_root_mean_squared_error: 3.2476 - val_loss: 6.1819 - val_y1_output_loss: 1.8058 - val_y2_output_loss: 4.2849 - val_y1_output_root_mean_squared_error: 1.3361 - val_y2_output_root_mean_squared_error: 2.0969
# Epoch 74/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5556 - y1_output_loss: 0.9642 - y2_output_loss: 2.5677 - y1_output_root_mean_squared_error: 0.9842 - y2_output_root_mean_squared_error: 1.6084 - val_loss: 6.3843 - val_y1_output_loss: 1.4156 - val_y2_output_loss: 4.9745 - val_y1_output_root_mean_squared_error: 1.1531 - val_y2_output_root_mean_squared_error: 2.2482
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4106 - y1_output_loss: 1.1858 - y2_output_loss: 3.2498 - y1_output_root_mean_squared_error: 1.0898 - y2_output_root_mean_squared_error: 1.7953 - val_loss: 7.5997 - val_y1_output_loss: 2.2627 - val_y2_output_loss: 5.1194 - val_y1_output_root_mean_squared_error: 1.5238 - val_y2_output_root_mean_squared_error: 2.2973
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0563 - y1_output_loss: 1.0138 - y2_output_loss: 3.0335 - y1_output_root_mean_squared_error: 1.0022 - y2_output_root_mean_squared_error: 1.7470 - val_loss: 5.6327 - val_y1_output_loss: 1.3019 - val_y2_output_loss: 4.2265 - val_y1_output_root_mean_squared_error: 1.1352 - val_y2_output_root_mean_squared_error: 2.0842
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0391 - y1_output_loss: 1.0270 - y2_output_loss: 3.0247 - y1_output_root_mean_squared_error: 1.0178 - y2_output_root_mean_squared_error: 1.7329 - val_loss: 5.5083 - val_y1_output_loss: 1.1222 - val_y2_output_loss: 4.4760 - val_y1_output_root_mean_squared_error: 1.0338 - val_y2_output_root_mean_squared_error: 2.1071
# Epoch 78/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.5814 - y1_output_loss: 0.7637 - y2_output_loss: 2.8009 - y1_output_root_mean_squared_error: 0.8729 - y2_output_root_mean_squared_error: 1.6791 - val_loss: 5.8565 - val_y1_output_loss: 1.0161 - val_y2_output_loss: 4.7034 - val_y1_output_root_mean_squared_error: 1.0021 - val_y2_output_root_mean_squared_error: 2.2028
# Epoch 79/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1389 - y1_output_loss: 1.3314 - y2_output_loss: 3.7642 - y1_output_root_mean_squared_error: 1.1590 - y2_output_root_mean_squared_error: 1.9482 - val_loss: 6.3639 - val_y1_output_loss: 2.1375 - val_y2_output_loss: 4.1822 - val_y1_output_root_mean_squared_error: 1.4419 - val_y2_output_root_mean_squared_error: 2.0700
# Epoch 80/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.6006 - y1_output_loss: 0.7789 - y2_output_loss: 2.7934 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.6781 - val_loss: 4.3574 - val_y1_output_loss: 0.7842 - val_y2_output_loss: 3.4931 - val_y1_output_root_mean_squared_error: 0.8802 - val_y2_output_root_mean_squared_error: 1.8928
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.8959 - y1_output_loss: 1.0938 - y2_output_loss: 2.8212 - y1_output_root_mean_squared_error: 1.0478 - y2_output_root_mean_squared_error: 1.6727 - val_loss: 4.4193 - val_y1_output_loss: 0.8261 - val_y2_output_loss: 3.5637 - val_y1_output_root_mean_squared_error: 0.8913 - val_y2_output_root_mean_squared_error: 1.9039
# Epoch 82/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7743 - y1_output_loss: 1.0325 - y2_output_loss: 2.7300 - y1_output_root_mean_squared_error: 1.0177 - y2_output_root_mean_squared_error: 1.6549 - val_loss: 4.9202 - val_y1_output_loss: 1.0951 - val_y2_output_loss: 3.7585 - val_y1_output_root_mean_squared_error: 1.0337 - val_y2_output_root_mean_squared_error: 1.9626
# Epoch 83/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0664 - y1_output_loss: 0.9298 - y2_output_loss: 3.1148 - y1_output_root_mean_squared_error: 0.9664 - y2_output_root_mean_squared_error: 1.7699 - val_loss: 6.4805 - val_y1_output_loss: 1.4223 - val_y2_output_loss: 4.8849 - val_y1_output_root_mean_squared_error: 1.1970 - val_y2_output_root_mean_squared_error: 2.2467
# Epoch 84/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4367 - y1_output_loss: 1.0990 - y2_output_loss: 3.3044 - y1_output_root_mean_squared_error: 1.0519 - y2_output_root_mean_squared_error: 1.8249 - val_loss: 4.4922 - val_y1_output_loss: 0.8597 - val_y2_output_loss: 3.5735 - val_y1_output_root_mean_squared_error: 0.9127 - val_y2_output_root_mean_squared_error: 1.9129
# Epoch 85/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7410 - y1_output_loss: 0.9369 - y2_output_loss: 2.7809 - y1_output_root_mean_squared_error: 0.9705 - y2_output_root_mean_squared_error: 1.6731 - val_loss: 4.1617 - val_y1_output_loss: 0.6537 - val_y2_output_loss: 3.4717 - val_y1_output_root_mean_squared_error: 0.8007 - val_y2_output_root_mean_squared_error: 1.8763
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.6181 - y1_output_loss: 0.7416 - y2_output_loss: 2.8764 - y1_output_root_mean_squared_error: 0.8631 - y2_output_root_mean_squared_error: 1.6951 - val_loss: 10.2121 - val_y1_output_loss: 3.0901 - val_y2_output_loss: 6.8496 - val_y1_output_root_mean_squared_error: 1.7706 - val_y2_output_root_mean_squared_error: 2.6603
# Epoch 87/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0904 - y1_output_loss: 0.6729 - y2_output_loss: 2.4187 - y1_output_root_mean_squared_error: 0.8233 - y2_output_root_mean_squared_error: 1.5533 - val_loss: 7.9222 - val_y1_output_loss: 1.0207 - val_y2_output_loss: 6.9449 - val_y1_output_root_mean_squared_error: 1.0097 - val_y2_output_root_mean_squared_error: 2.6273
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2373 - y1_output_loss: 1.1153 - y2_output_loss: 3.1600 - y1_output_root_mean_squared_error: 1.0555 - y2_output_root_mean_squared_error: 1.7673 - val_loss: 11.0737 - val_y1_output_loss: 2.5012 - val_y2_output_loss: 8.5959 - val_y1_output_root_mean_squared_error: 1.5434 - val_y2_output_root_mean_squared_error: 2.9482
# Epoch 89/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3113 - y1_output_loss: 0.6922 - y2_output_loss: 2.6382 - y1_output_root_mean_squared_error: 0.8321 - y2_output_root_mean_squared_error: 1.6183 - val_loss: 12.3099 - val_y1_output_loss: 1.6805 - val_y2_output_loss: 10.7603 - val_y1_output_root_mean_squared_error: 1.2990 - val_y2_output_root_mean_squared_error: 3.2592
# Epoch 90/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1128 - y1_output_loss: 2.0245 - y2_output_loss: 5.0614 - y1_output_root_mean_squared_error: 1.4249 - y2_output_root_mean_squared_error: 2.2544 - val_loss: 7.5587 - val_y1_output_loss: 1.9459 - val_y2_output_loss: 5.7111 - val_y1_output_root_mean_squared_error: 1.3851 - val_y2_output_root_mean_squared_error: 2.3749
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4191 - y1_output_loss: 0.7797 - y2_output_loss: 2.6423 - y1_output_root_mean_squared_error: 0.8765 - y2_output_root_mean_squared_error: 1.6281 - val_loss: 6.6044 - val_y1_output_loss: 1.5879 - val_y2_output_loss: 4.9761 - val_y1_output_root_mean_squared_error: 1.2334 - val_y2_output_root_mean_squared_error: 2.2546
# Epoch 92/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7612 - y1_output_loss: 0.8709 - y2_output_loss: 2.9437 - y1_output_root_mean_squared_error: 0.9234 - y2_output_root_mean_squared_error: 1.7054 - val_loss: 17.9410 - val_y1_output_loss: 4.1572 - val_y2_output_loss: 13.9726 - val_y1_output_root_mean_squared_error: 2.0427 - val_y2_output_root_mean_squared_error: 3.7106
# Epoch 93/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8357 - y1_output_loss: 0.6568 - y2_output_loss: 2.1598 - y1_output_root_mean_squared_error: 0.8123 - y2_output_root_mean_squared_error: 1.4751 - val_loss: 3.8541 - val_y1_output_loss: 0.5801 - val_y2_output_loss: 3.2410 - val_y1_output_root_mean_squared_error: 0.7482 - val_y2_output_root_mean_squared_error: 1.8150
# Epoch 94/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0899 - y1_output_loss: 0.6519 - y2_output_loss: 2.4237 - y1_output_root_mean_squared_error: 0.8068 - y2_output_root_mean_squared_error: 1.5617 - val_loss: 4.0815 - val_y1_output_loss: 0.5854 - val_y2_output_loss: 3.3944 - val_y1_output_root_mean_squared_error: 0.7609 - val_y2_output_root_mean_squared_error: 1.8715
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9278 - y1_output_loss: 0.6624 - y2_output_loss: 2.2564 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.5059 - val_loss: 4.0480 - val_y1_output_loss: 0.8748 - val_y2_output_loss: 3.1609 - val_y1_output_root_mean_squared_error: 0.9178 - val_y2_output_root_mean_squared_error: 1.7905
# Epoch 96/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7449 - y1_output_loss: 0.5961 - y2_output_loss: 2.1499 - y1_output_root_mean_squared_error: 0.7723 - y2_output_root_mean_squared_error: 1.4658 - val_loss: 9.0854 - val_y1_output_loss: 2.7429 - val_y2_output_loss: 6.3083 - val_y1_output_root_mean_squared_error: 1.6646 - val_y2_output_root_mean_squared_error: 2.5129
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.4707 - y1_output_loss: 1.0051 - y2_output_loss: 3.4435 - y1_output_root_mean_squared_error: 1.0048 - y2_output_root_mean_squared_error: 1.8604 - val_loss: 4.4715 - val_y1_output_loss: 0.7338 - val_y2_output_loss: 3.6973 - val_y1_output_root_mean_squared_error: 0.8668 - val_y2_output_root_mean_squared_error: 1.9288
# Epoch 98/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6251 - y1_output_loss: 0.6240 - y2_output_loss: 1.9861 - y1_output_root_mean_squared_error: 0.7931 - y2_output_root_mean_squared_error: 1.4128 - val_loss: 7.4319 - val_y1_output_loss: 1.3094 - val_y2_output_loss: 6.1295 - val_y1_output_root_mean_squared_error: 1.1178 - val_y2_output_root_mean_squared_error: 2.4864
# Epoch 99/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.5421 - y1_output_loss: 0.5491 - y2_output_loss: 1.9764 - y1_output_root_mean_squared_error: 0.7422 - y2_output_root_mean_squared_error: 1.4111 - val_loss: 3.9661 - val_y1_output_loss: 0.7669 - val_y2_output_loss: 3.1452 - val_y1_output_root_mean_squared_error: 0.8736 - val_y2_output_root_mean_squared_error: 1.7897
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9908 - y1_output_loss: 0.6780 - y2_output_loss: 2.3289 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.5267 - val_loss: 9.8112 - val_y1_output_loss: 2.5645 - val_y2_output_loss: 7.3481 - val_y1_output_root_mean_squared_error: 1.6016 - val_y2_output_root_mean_squared_error: 2.6919
# Epoch 101/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2716 - y1_output_loss: 0.7928 - y2_output_loss: 2.4508 - y1_output_root_mean_squared_error: 0.8940 - y2_output_root_mean_squared_error: 1.5724 - val_loss: 5.0108 - val_y1_output_loss: 0.6940 - val_y2_output_loss: 4.2126 - val_y1_output_root_mean_squared_error: 0.8239 - val_y2_output_root_mean_squared_error: 2.0813
# Epoch 102/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.4620 - y1_output_loss: 0.9416 - y2_output_loss: 3.5230 - y1_output_root_mean_squared_error: 0.9673 - y2_output_root_mean_squared_error: 1.8779 - val_loss: 14.1185 - val_y1_output_loss: 3.9140 - val_y2_output_loss: 9.8930 - val_y1_output_root_mean_squared_error: 1.9906 - val_y2_output_root_mean_squared_error: 3.1869
# Epoch 103/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6119 - y1_output_loss: 0.6038 - y2_output_loss: 2.0409 - y1_output_root_mean_squared_error: 0.7626 - y2_output_root_mean_squared_error: 1.4249 - val_loss: 13.3640 - val_y1_output_loss: 3.6910 - val_y2_output_loss: 9.4607 - val_y1_output_root_mean_squared_error: 1.9236 - val_y2_output_root_mean_squared_error: 3.1087
# Epoch 104/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0038 - y1_output_loss: 0.6902 - y2_output_loss: 2.2907 - y1_output_root_mean_squared_error: 0.8326 - y2_output_root_mean_squared_error: 1.5201 - val_loss: 3.5148 - val_y1_output_loss: 0.5460 - val_y2_output_loss: 2.8956 - val_y1_output_root_mean_squared_error: 0.7287 - val_y2_output_root_mean_squared_error: 1.7274
# Epoch 105/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4168 - y1_output_loss: 0.5583 - y2_output_loss: 1.8676 - y1_output_root_mean_squared_error: 0.7452 - y2_output_root_mean_squared_error: 1.3644 - val_loss: 4.7815 - val_y1_output_loss: 0.6313 - val_y2_output_loss: 4.1749 - val_y1_output_root_mean_squared_error: 0.7918 - val_y2_output_root_mean_squared_error: 2.0382
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.9128 - y1_output_loss: 0.5891 - y2_output_loss: 2.3075 - y1_output_root_mean_squared_error: 0.7710 - y2_output_root_mean_squared_error: 1.5226 - val_loss: 4.2920 - val_y1_output_loss: 0.6255 - val_y2_output_loss: 3.6329 - val_y1_output_root_mean_squared_error: 0.7965 - val_y2_output_root_mean_squared_error: 1.9125
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6405 - y1_output_loss: 0.6008 - y2_output_loss: 2.0776 - y1_output_root_mean_squared_error: 0.7709 - y2_output_root_mean_squared_error: 1.4304 - val_loss: 23.9829 - val_y1_output_loss: 6.2653 - val_y2_output_loss: 17.5678 - val_y1_output_root_mean_squared_error: 2.5275 - val_y2_output_root_mean_squared_error: 4.1946
# Epoch 108/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8603 - y1_output_loss: 0.8722 - y2_output_loss: 2.9538 - y1_output_root_mean_squared_error: 0.9382 - y2_output_root_mean_squared_error: 1.7263 - val_loss: 4.2131 - val_y1_output_loss: 0.8173 - val_y2_output_loss: 3.3163 - val_y1_output_root_mean_squared_error: 0.8989 - val_y2_output_root_mean_squared_error: 1.8453
# Epoch 109/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9251 - y1_output_loss: 0.8684 - y2_output_loss: 3.0261 - y1_output_root_mean_squared_error: 0.9350 - y2_output_root_mean_squared_error: 1.7467 - val_loss: 3.8269 - val_y1_output_loss: 0.5855 - val_y2_output_loss: 3.2168 - val_y1_output_root_mean_squared_error: 0.7596 - val_y2_output_root_mean_squared_error: 1.8028
# Epoch 110/500
# 614/614 [==============================] - 0s 175us/sample - loss: 2.7581 - y1_output_loss: 0.5266 - y2_output_loss: 2.2087 - y1_output_root_mean_squared_error: 0.7289 - y2_output_root_mean_squared_error: 1.4922 - val_loss: 3.5985 - val_y1_output_loss: 0.6455 - val_y2_output_loss: 2.8549 - val_y1_output_root_mean_squared_error: 0.8103 - val_y2_output_root_mean_squared_error: 1.7152
# Epoch 111/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9750 - y1_output_loss: 0.6013 - y2_output_loss: 2.3677 - y1_output_root_mean_squared_error: 0.7749 - y2_output_root_mean_squared_error: 1.5410 - val_loss: 5.5889 - val_y1_output_loss: 1.8159 - val_y2_output_loss: 3.5977 - val_y1_output_root_mean_squared_error: 1.3690 - val_y2_output_root_mean_squared_error: 1.9274
# Epoch 112/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0442 - y1_output_loss: 0.7157 - y2_output_loss: 2.3362 - y1_output_root_mean_squared_error: 0.8469 - y2_output_root_mean_squared_error: 1.5254 - val_loss: 10.2007 - val_y1_output_loss: 2.2430 - val_y2_output_loss: 7.9381 - val_y1_output_root_mean_squared_error: 1.5140 - val_y2_output_root_mean_squared_error: 2.8122
# Epoch 113/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3922 - y1_output_loss: 0.5187 - y2_output_loss: 1.9589 - y1_output_root_mean_squared_error: 0.7190 - y2_output_root_mean_squared_error: 1.3694 - val_loss: 8.4989 - val_y1_output_loss: 1.4750 - val_y2_output_loss: 6.9981 - val_y1_output_root_mean_squared_error: 1.1902 - val_y2_output_root_mean_squared_error: 2.6612
# Epoch 114/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6788 - y1_output_loss: 0.6482 - y2_output_loss: 2.0086 - y1_output_root_mean_squared_error: 0.8077 - y2_output_root_mean_squared_error: 1.4235 - val_loss: 4.4593 - val_y1_output_loss: 0.6733 - val_y2_output_loss: 3.7255 - val_y1_output_root_mean_squared_error: 0.8082 - val_y2_output_root_mean_squared_error: 1.9509
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0008 - y1_output_loss: 0.6032 - y2_output_loss: 2.3817 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.5497 - val_loss: 3.4185 - val_y1_output_loss: 0.5115 - val_y2_output_loss: 2.8077 - val_y1_output_root_mean_squared_error: 0.7211 - val_y2_output_root_mean_squared_error: 1.7025
# Epoch 116/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.0896 - y1_output_loss: 0.4493 - y2_output_loss: 1.6251 - y1_output_root_mean_squared_error: 0.6710 - y2_output_root_mean_squared_error: 1.2804 - val_loss: 3.4697 - val_y1_output_loss: 0.4977 - val_y2_output_loss: 2.9739 - val_y1_output_root_mean_squared_error: 0.7007 - val_y2_output_root_mean_squared_error: 1.7259
# Epoch 117/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1101 - y1_output_loss: 0.4725 - y2_output_loss: 1.6299 - y1_output_root_mean_squared_error: 0.6880 - y2_output_root_mean_squared_error: 1.2793 - val_loss: 3.5703 - val_y1_output_loss: 0.5283 - val_y2_output_loss: 3.0139 - val_y1_output_root_mean_squared_error: 0.7352 - val_y2_output_root_mean_squared_error: 1.7406
# Epoch 118/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5162 - y1_output_loss: 0.5479 - y2_output_loss: 1.9724 - y1_output_root_mean_squared_error: 0.7312 - y2_output_root_mean_squared_error: 1.4077 - val_loss: 9.4612 - val_y1_output_loss: 2.3697 - val_y2_output_loss: 6.8589 - val_y1_output_root_mean_squared_error: 1.5570 - val_y2_output_root_mean_squared_error: 2.6527
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1938 - y1_output_loss: 0.6076 - y2_output_loss: 2.5695 - y1_output_root_mean_squared_error: 0.7807 - y2_output_root_mean_squared_error: 1.6076 - val_loss: 8.7947 - val_y1_output_loss: 1.1629 - val_y2_output_loss: 7.7742 - val_y1_output_root_mean_squared_error: 1.0859 - val_y2_output_root_mean_squared_error: 2.7596
# Epoch 120/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4716 - y1_output_loss: 0.5188 - y2_output_loss: 1.9468 - y1_output_root_mean_squared_error: 0.7218 - y2_output_root_mean_squared_error: 1.3966 - val_loss: 3.3002 - val_y1_output_loss: 0.6551 - val_y2_output_loss: 2.6109 - val_y1_output_root_mean_squared_error: 0.7958 - val_y2_output_root_mean_squared_error: 1.6330
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6100 - y1_output_loss: 0.1494 - y2_output_loss: 0.4636 - y1_output_root_mean_squared_error: 0.3866 - y2_output_root_mean_squared_error: 0.6786 - val_loss: 1.9084 - val_y1_output_loss: 0.2999 - val_y2_output_loss: 1.6045 - val_y1_output_root_mean_squared_error: 0.5516 - val_y2_output_root_mean_squared_error: 1.2665
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5033 - y1_output_loss: 0.1220 - y2_output_loss: 0.3796 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.6169 - val_loss: 1.6800 - val_y1_output_loss: 0.3920 - val_y2_output_loss: 1.3343 - val_y1_output_root_mean_squared_error: 0.6074 - val_y2_output_root_mean_squared_error: 1.1450
# Epoch 463/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6738 - y1_output_loss: 0.1760 - y2_output_loss: 0.5116 - y1_output_root_mean_squared_error: 0.4196 - y2_output_root_mean_squared_error: 0.7055 - val_loss: 3.4982 - val_y1_output_loss: 0.2212 - val_y2_output_loss: 3.2800 - val_y1_output_root_mean_squared_error: 0.4669 - val_y2_output_root_mean_squared_error: 1.8111
# Epoch 464/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6153 - y1_output_loss: 0.1241 - y2_output_loss: 0.4889 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.7020 - val_loss: 0.9728 - val_y1_output_loss: 0.2566 - val_y2_output_loss: 0.7096 - val_y1_output_root_mean_squared_error: 0.5061 - val_y2_output_root_mean_squared_error: 0.8466
# Epoch 465/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5570 - y1_output_loss: 0.1306 - y2_output_loss: 0.4225 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.6527 - val_loss: 1.0775 - val_y1_output_loss: 0.2831 - val_y2_output_loss: 0.7820 - val_y1_output_root_mean_squared_error: 0.5336 - val_y2_output_root_mean_squared_error: 0.8903
# Epoch 466/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.7897 - y1_output_loss: 0.1700 - y2_output_loss: 0.6322 - y1_output_root_mean_squared_error: 0.4139 - y2_output_root_mean_squared_error: 0.7864 - val_loss: 3.4025 - val_y1_output_loss: 0.2746 - val_y2_output_loss: 3.1638 - val_y1_output_root_mean_squared_error: 0.5153 - val_y2_output_root_mean_squared_error: 1.7712
# Epoch 467/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4900 - y1_output_loss: 0.1276 - y2_output_loss: 0.3679 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.6054 - val_loss: 1.8040 - val_y1_output_loss: 0.7769 - val_y2_output_loss: 0.9940 - val_y1_output_root_mean_squared_error: 0.8942 - val_y2_output_root_mean_squared_error: 1.0022
# Epoch 468/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.4770 - y1_output_loss: 0.2574 - y2_output_loss: 1.2167 - y1_output_root_mean_squared_error: 0.5069 - y2_output_root_mean_squared_error: 1.1045 - val_loss: 1.2136 - val_y1_output_loss: 0.3056 - val_y2_output_loss: 0.9213 - val_y1_output_root_mean_squared_error: 0.5548 - val_y2_output_root_mean_squared_error: 0.9517
# Epoch 469/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6364 - y1_output_loss: 0.1554 - y2_output_loss: 0.4810 - y1_output_root_mean_squared_error: 0.3953 - y2_output_root_mean_squared_error: 0.6929 - val_loss: 1.2747 - val_y1_output_loss: 0.2703 - val_y2_output_loss: 1.0285 - val_y1_output_root_mean_squared_error: 0.5116 - val_y2_output_root_mean_squared_error: 1.0065
# Epoch 470/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.8025 - y1_output_loss: 0.1520 - y2_output_loss: 0.6529 - y1_output_root_mean_squared_error: 0.3881 - y2_output_root_mean_squared_error: 0.8074 - val_loss: 1.6216 - val_y1_output_loss: 0.3447 - val_y2_output_loss: 1.2954 - val_y1_output_root_mean_squared_error: 0.5879 - val_y2_output_root_mean_squared_error: 1.1296
# Epoch 471/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6033 - y1_output_loss: 0.1463 - y2_output_loss: 0.4605 - y1_output_root_mean_squared_error: 0.3831 - y2_output_root_mean_squared_error: 0.6757 - val_loss: 2.4046 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 2.1858 - val_y1_output_root_mean_squared_error: 0.5069 - val_y2_output_root_mean_squared_error: 1.4655
# Epoch 472/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6457 - y1_output_loss: 0.1515 - y2_output_loss: 0.4892 - y1_output_root_mean_squared_error: 0.3899 - y2_output_root_mean_squared_error: 0.7026 - val_loss: 1.0074 - val_y1_output_loss: 0.2450 - val_y2_output_loss: 0.7548 - val_y1_output_root_mean_squared_error: 0.4939 - val_y2_output_root_mean_squared_error: 0.8737
# Epoch 473/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6189 - y1_output_loss: 0.1568 - y2_output_loss: 0.4583 - y1_output_root_mean_squared_error: 0.3955 - y2_output_root_mean_squared_error: 0.6801 - val_loss: 1.3162 - val_y1_output_loss: 0.3417 - val_y2_output_loss: 0.9913 - val_y1_output_root_mean_squared_error: 0.5843 - val_y2_output_root_mean_squared_error: 0.9873
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5373 - y1_output_loss: 0.1462 - y2_output_loss: 0.3868 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.6248 - val_loss: 1.1768 - val_y1_output_loss: 0.2083 - val_y2_output_loss: 0.9846 - val_y1_output_root_mean_squared_error: 0.4503 - val_y2_output_root_mean_squared_error: 0.9869
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5892 - y1_output_loss: 0.1466 - y2_output_loss: 0.4402 - y1_output_root_mean_squared_error: 0.3833 - y2_output_root_mean_squared_error: 0.6650 - val_loss: 1.0993 - val_y1_output_loss: 0.2742 - val_y2_output_loss: 0.8081 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.9070
# Epoch 476/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.8113 - y1_output_loss: 0.1580 - y2_output_loss: 0.6461 - y1_output_root_mean_squared_error: 0.3992 - y2_output_root_mean_squared_error: 0.8075 - val_loss: 1.2042 - val_y1_output_loss: 0.2625 - val_y2_output_loss: 0.9443 - val_y1_output_root_mean_squared_error: 0.5117 - val_y2_output_root_mean_squared_error: 0.9707
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.1394 - y1_output_loss: 0.2049 - y2_output_loss: 0.9240 - y1_output_root_mean_squared_error: 0.4548 - y2_output_root_mean_squared_error: 0.9657 - val_loss: 1.2600 - val_y1_output_loss: 0.2754 - val_y2_output_loss: 0.9667 - val_y1_output_root_mean_squared_error: 0.5273 - val_y2_output_root_mean_squared_error: 0.9909
# Epoch 478/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6005 - y1_output_loss: 0.1283 - y2_output_loss: 0.4726 - y1_output_root_mean_squared_error: 0.3580 - y2_output_root_mean_squared_error: 0.6872 - val_loss: 3.3363 - val_y1_output_loss: 0.2584 - val_y2_output_loss: 3.1329 - val_y1_output_root_mean_squared_error: 0.4960 - val_y2_output_root_mean_squared_error: 1.7579
# Epoch 479/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5675 - y1_output_loss: 0.1359 - y2_output_loss: 0.4302 - y1_output_root_mean_squared_error: 0.3689 - y2_output_root_mean_squared_error: 0.6568 - val_loss: 1.6735 - val_y1_output_loss: 0.2844 - val_y2_output_loss: 1.3963 - val_y1_output_root_mean_squared_error: 0.5354 - val_y2_output_root_mean_squared_error: 1.1776
# Epoch 480/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5684 - y1_output_loss: 0.1321 - y2_output_loss: 0.4352 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.6609 - val_loss: 1.6621 - val_y1_output_loss: 0.4847 - val_y2_output_loss: 1.1571 - val_y1_output_root_mean_squared_error: 0.7034 - val_y2_output_root_mean_squared_error: 1.0804
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.7476 - y1_output_loss: 0.1501 - y2_output_loss: 0.5987 - y1_output_root_mean_squared_error: 0.3876 - y2_output_root_mean_squared_error: 0.7729 - val_loss: 1.7297 - val_y1_output_loss: 0.2592 - val_y2_output_loss: 1.4967 - val_y1_output_root_mean_squared_error: 0.4965 - val_y2_output_root_mean_squared_error: 1.2178
# Epoch 482/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5175 - y1_output_loss: 0.1204 - y2_output_loss: 0.3999 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.6293 - val_loss: 1.2008 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.9909 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.9934
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5474 - y1_output_loss: 0.1443 - y2_output_loss: 0.3998 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.6341 - val_loss: 1.0766 - val_y1_output_loss: 0.2392 - val_y2_output_loss: 0.8478 - val_y1_output_root_mean_squared_error: 0.4840 - val_y2_output_root_mean_squared_error: 0.9178
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4829 - y1_output_loss: 0.1247 - y2_output_loss: 0.3548 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5978 - val_loss: 1.3574 - val_y1_output_loss: 0.2027 - val_y2_output_loss: 1.1763 - val_y1_output_root_mean_squared_error: 0.4431 - val_y2_output_root_mean_squared_error: 1.0775
# Epoch 485/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5815 - y1_output_loss: 0.1238 - y2_output_loss: 0.4544 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.6764 - val_loss: 1.1625 - val_y1_output_loss: 0.3049 - val_y2_output_loss: 0.8433 - val_y1_output_root_mean_squared_error: 0.5544 - val_y2_output_root_mean_squared_error: 0.9247
# Epoch 486/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4630 - y1_output_loss: 0.1271 - y2_output_loss: 0.3711 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5789 - val_loss: 13.8224 - val_y1_output_loss: 0.5872 - val_y2_output_loss: 13.1946 - val_y1_output_root_mean_squared_error: 0.7764 - val_y2_output_root_mean_squared_error: 3.6359
# Epoch 487/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.2136 - y1_output_loss: 0.2908 - y2_output_loss: 0.9300 - y1_output_root_mean_squared_error: 0.5399 - y2_output_root_mean_squared_error: 0.9603 - val_loss: 3.7421 - val_y1_output_loss: 0.4715 - val_y2_output_loss: 3.3063 - val_y1_output_root_mean_squared_error: 0.6905 - val_y2_output_root_mean_squared_error: 1.8070
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5764 - y1_output_loss: 0.1433 - y2_output_loss: 0.4289 - y1_output_root_mean_squared_error: 0.3797 - y2_output_root_mean_squared_error: 0.6574 - val_loss: 1.0047 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 0.7871 - val_y1_output_root_mean_squared_error: 0.4706 - val_y2_output_root_mean_squared_error: 0.8850
# Epoch 489/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5591 - y1_output_loss: 0.1280 - y2_output_loss: 0.4302 - y1_output_root_mean_squared_error: 0.3594 - y2_output_root_mean_squared_error: 0.6557 - val_loss: 1.0996 - val_y1_output_loss: 0.2294 - val_y2_output_loss: 0.8471 - val_y1_output_root_mean_squared_error: 0.4789 - val_y2_output_root_mean_squared_error: 0.9329
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6608 - y1_output_loss: 0.1608 - y2_output_loss: 0.4983 - y1_output_root_mean_squared_error: 0.4014 - y2_output_root_mean_squared_error: 0.7069 - val_loss: 1.2148 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.9433 - val_y1_output_root_mean_squared_error: 0.5111 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 491/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4494 - y1_output_loss: 0.1250 - y2_output_loss: 0.3257 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5721 - val_loss: 2.3174 - val_y1_output_loss: 0.3629 - val_y2_output_loss: 2.0144 - val_y1_output_root_mean_squared_error: 0.5842 - val_y2_output_root_mean_squared_error: 1.4058
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5625 - y1_output_loss: 0.1246 - y2_output_loss: 0.4334 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.6609 - val_loss: 1.0869 - val_y1_output_loss: 0.2287 - val_y2_output_loss: 0.8549 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.9261
# Epoch 493/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5043 - y1_output_loss: 0.1170 - y2_output_loss: 0.3863 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.6223 - val_loss: 1.0440 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 0.8207 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 0.9120
# Epoch 494/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5529 - y1_output_loss: 0.1368 - y2_output_loss: 0.4534 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.6512 - val_loss: 1.9836 - val_y1_output_loss: 0.5744 - val_y2_output_loss: 1.4528 - val_y1_output_root_mean_squared_error: 0.7562 - val_y2_output_root_mean_squared_error: 1.1882
# Epoch 495/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6160 - y1_output_loss: 0.1429 - y2_output_loss: 0.4729 - y1_output_root_mean_squared_error: 0.3753 - y2_output_root_mean_squared_error: 0.6893 - val_loss: 1.5399 - val_y1_output_loss: 0.3701 - val_y2_output_loss: 1.2214 - val_y1_output_root_mean_squared_error: 0.5901 - val_y2_output_root_mean_squared_error: 1.0917
# Epoch 496/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7385 - y1_output_loss: 0.1784 - y2_output_loss: 0.5537 - y1_output_root_mean_squared_error: 0.4244 - y2_output_root_mean_squared_error: 0.7473 - val_loss: 1.5112 - val_y1_output_loss: 0.2303 - val_y2_output_loss: 1.3006 - val_y1_output_root_mean_squared_error: 0.4702 - val_y2_output_root_mean_squared_error: 1.1358
# Epoch 497/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5601 - y1_output_loss: 0.1394 - y2_output_loss: 0.4190 - y1_output_root_mean_squared_error: 0.3742 - y2_output_root_mean_squared_error: 0.6482 - val_loss: 1.0906 - val_y1_output_loss: 0.2318 - val_y2_output_loss: 0.8656 - val_y1_output_root_mean_squared_error: 0.4721 - val_y2_output_root_mean_squared_error: 0.9315
# Epoch 498/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5193 - y1_output_loss: 0.1145 - y2_output_loss: 0.4019 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.6357 - val_loss: 1.1043 - val_y1_output_loss: 0.2083 - val_y2_output_loss: 0.9107 - val_y1_output_root_mean_squared_error: 0.4515 - val_y2_output_root_mean_squared_error: 0.9489
# Epoch 499/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4531 - y1_output_loss: 0.1205 - y2_output_loss: 0.3310 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.5762 - val_loss: 1.1224 - val_y1_output_loss: 0.2227 - val_y2_output_loss: 0.8926 - val_y1_output_root_mean_squared_error: 0.4687 - val_y2_output_root_mean_squared_error: 0.9501
# Epoch 500/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6208 - y1_output_loss: 0.1282 - y2_output_loss: 0.4882 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.7013 - val_loss: 0.9585 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.7464 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.8648

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.9585 - y1_output_loss: 0.2116 - y2_output_loss: 0.7415 - y1_output_root_mean_squared_error: 0.4589 - y2_output_root_mean_squared_error: 0.8648
# Loss = 0.9584921064314904, Y1_loss = 0.2116132527589798, Y1_mse = 0.4588916003704071, Y2_loss = 0.741497814655304, Y2_mse = 0.864818274974823

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
